# %% [markdown]
# # **Producto Integrador de Aprendizaje**
# ---
# Tema: **Entrenamiento de una CNN usando CIFAR-100**\
# Inteligencia Artificial; IB
#
#
# > 1877436, Jesús Emmanuel Guerrero Cortez \
# > 1943543, Haziel Jair Sánchez Barrón \
# > 1378118, Víctor Manuel Castañeda de León \
# > 1841262, Bryan David Garrido \
# > 1799686, Jesús Quezada Oviedo

# %%
import tensorflow as tf
#Importación de base de trabajo y librerías 
from tensorflow.keras import datasets, layers, models
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.applications.inception_v3 import InceptionV3
#VGG16 con fine-tuning, aunque puede ser empleado con cualquier modelo
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
#____________________________________________________________________#
from datetime import datetime
import pandas as pd
import numpy as np
import pytz
import random
import matplotlib.pyplot as plt

#Arreglo se usará como registro, aunque bien se podrían enviar los valores a archivo csv.
historyarray = [0]

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar100.load_data(label_mode='coarse')
#Normalización (abajo) e importación del data set CIFAR100 (arriba), con conjuntos de prueba y entrenamiento.
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step
# 169017344/169001437 [==============================] - 3s 0us/step

# %%
#Inicialmente, optamos por eliminar el arreglo de strings para etiquetas, puesto que equivaldría a 100 clases.
#Para evitar la fatiga de copiar y pegar, se procesaron los atributos a partir de un archivo csv (sep. por coma, tipo str); creado.
#Al final, para aumentar exactitud, se redujo la ultima capa profunda a 20 nodos, o superclases.
#Valores de shape de set de entrenamiento se usarán al trabajar con modelo de transfer learning.

'''
CIFAR100_attributes = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

'''
Coarse_labels = ['aquatic_mammals', 'fish', 'flowers', 'food_containers', 'fruit_and_vegetables', 
                'household_electrical_devices', 'household_furniture', 'insects', 'large_carnivores', 
                'large_man-made_outdoor_things', 'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores', 
                'medium_mammals', 'non-insect_invertebrates', 'people', 'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2']

data_size, img_rows, img_cols, img_channels = train_images.shape

plt.figure(figsize=(10,10))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(Coarse_labels[train_labels[i][0]])
plt.show()

# %%
#Imágenes a RGB, 32x32x(3_canales); capas superficiales
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.20))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.20))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

# %%
#Modelo de capas profundas
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(20))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 256)         147712
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dense_1 (Dense)             (None, 1024)              4195328
#
#  dense_2 (Dense)             (None, 256)               262400
#
#  dense_3 (Dense)             (None, 20)                5140
#
# =================================================================
# Total params: 5,719,572
# Trainable params: 5,719,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Esta celda tiene por intención guardar el mejor modelo a partir del peso de sus características; solo tiene utilidad en fine-tuning
# ModelCheckpoint callback - guardar los mejores pesos (weights).
tl_checkpoint_1 = ModelCheckpoint(filepath='tl_model_v1.weights.best.hdf5',
                                  save_best_only=True,
                                  verbose=1)

# Si no existe cambio en la perdida durante la validación, se detiene.
early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

#Aceleración con GPU (demasiado útil). Fundamentos disponibles en: https://colab.research.google.com/notebooks/gpu.ipynb#scrollTo=sXnDmXR7RDr2

tf.keras.optimizers.Adagrad(
    learning_rate=0.00005, initial_accumulator_value=0.1, epsilon=1e-07, name="Adagrad"
)

tf.keras.optimizers.Adadelta(
    learning_rate=0.001, rho=0.95, epsilon=1e-07, name="Adadelta"
)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

def train_model(model, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = model.fit(train_images, train_labels, epochs = epochs, steps_per_epoch = steps_per_epoch, validation_data = (test_images, test_labels), validation_steps = validation_steps, callbacks=[tl_checkpoint_1, early_stop])
  return(history)
# Out:
# Found GPU at: /device:GPU:0

# %%
SIMPLE_MODEL_history = train_model(model, 60, 150, 20)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/60
# 150/150 [==============================] - ETA: 0s - loss: 2.7830 - accuracy: 0.1225
# Epoch 00001: val_loss improved from inf to 2.68080, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 38s 49ms/step - loss: 2.7830 - accuracy: 0.1225 - val_loss: 2.6808 - val_accuracy: 0.1645
# Epoch 2/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.5534 - accuracy: 0.1995
# Epoch 00002: val_loss improved from 2.68080 to 2.45523, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 42ms/step - loss: 2.5530 - accuracy: 0.1998 - val_loss: 2.4552 - val_accuracy: 0.2362
# Epoch 3/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.3941 - accuracy: 0.2460
# Epoch 00003: val_loss improved from 2.45523 to 2.28406, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 2.3947 - accuracy: 0.2459 - val_loss: 2.2841 - val_accuracy: 0.2785
# Epoch 4/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.2684 - accuracy: 0.2914
# Epoch 00004: val_loss improved from 2.28406 to 2.26146, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 2.2684 - accuracy: 0.2914 - val_loss: 2.2615 - val_accuracy: 0.2987
# Epoch 5/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.1776 - accuracy: 0.3170
# Epoch 00005: val_loss improved from 2.26146 to 2.11365, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 7s 43ms/step - loss: 2.1776 - accuracy: 0.3170 - val_loss: 2.1136 - val_accuracy: 0.3399
# Epoch 6/60
# 150/150 [==============================] - ETA: 0s - loss: 2.1048 - accuracy: 0.3416
# Epoch 00006: val_loss improved from 2.11365 to 2.02440, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 2.1048 - accuracy: 0.3416 - val_loss: 2.0244 - val_accuracy: 0.3684
# Epoch 7/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.0514 - accuracy: 0.3591
# Epoch 00007: val_loss improved from 2.02440 to 2.01028, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 2.0518 - accuracy: 0.3589 - val_loss: 2.0103 - val_accuracy: 0.3718
# Epoch 8/60
# 149/150 [============================>.] - ETA: 0s - loss: 2.0147 - accuracy: 0.3707
# Epoch 00008: val_loss improved from 2.01028 to 1.93645, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 2.0149 - accuracy: 0.3709 - val_loss: 1.9365 - val_accuracy: 0.3967
# Epoch 9/60
# 150/150 [==============================] - ETA: 0s - loss: 1.9645 - accuracy: 0.3867
# Epoch 00009: val_loss did not improve from 1.93645
# 150/150 [==============================] - 6s 42ms/step - loss: 1.9645 - accuracy: 0.3867 - val_loss: 1.9581 - val_accuracy: 0.3951
# Epoch 10/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.9377 - accuracy: 0.3942
# Epoch 00010: val_loss improved from 1.93645 to 1.87475, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.9375 - accuracy: 0.3942 - val_loss: 1.8747 - val_accuracy: 0.4181
# Epoch 11/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.9035 - accuracy: 0.4028
# Epoch 00011: val_loss improved from 1.87475 to 1.86823, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.9037 - accuracy: 0.4027 - val_loss: 1.8682 - val_accuracy: 0.4198
# Epoch 12/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.8686 - accuracy: 0.4146
# Epoch 00012: val_loss improved from 1.86823 to 1.80350, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.8682 - accuracy: 0.4146 - val_loss: 1.8035 - val_accuracy: 0.4358
# Epoch 13/60
# 150/150 [==============================] - ETA: 0s - loss: 1.8389 - accuracy: 0.4238
# Epoch 00013: val_loss did not improve from 1.80350
# 150/150 [==============================] - 6s 42ms/step - loss: 1.8389 - accuracy: 0.4238 - val_loss: 1.8273 - val_accuracy: 0.4334
# Epoch 14/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.8256 - accuracy: 0.4299
# Epoch 00014: val_loss improved from 1.80350 to 1.79981, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.8260 - accuracy: 0.4297 - val_loss: 1.7998 - val_accuracy: 0.4386
# Epoch 15/60
# 150/150 [==============================] - ETA: 0s - loss: 1.8030 - accuracy: 0.4335
# Epoch 00015: val_loss improved from 1.79981 to 1.76302, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.8030 - accuracy: 0.4335 - val_loss: 1.7630 - val_accuracy: 0.4523
# Epoch 16/60
# 150/150 [==============================] - ETA: 0s - loss: 1.7767 - accuracy: 0.4426
# Epoch 00016: val_loss did not improve from 1.76302
# 150/150 [==============================] - 6s 42ms/step - loss: 1.7767 - accuracy: 0.4426 - val_loss: 1.7729 - val_accuracy: 0.4458
# Epoch 17/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.7642 - accuracy: 0.4483
# Epoch 00017: val_loss improved from 1.76302 to 1.73768, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.7641 - accuracy: 0.4483 - val_loss: 1.7377 - val_accuracy: 0.4621
# Epoch 18/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.7367 - accuracy: 0.4560
# Epoch 00018: val_loss improved from 1.73768 to 1.72745, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.7363 - accuracy: 0.4560 - val_loss: 1.7274 - val_accuracy: 0.4593
# Epoch 19/60
# 150/150 [==============================] - ETA: 0s - loss: 1.7192 - accuracy: 0.4588
# Epoch 00019: val_loss improved from 1.72745 to 1.68119, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.7192 - accuracy: 0.4588 - val_loss: 1.6812 - val_accuracy: 0.4677
# Epoch 20/60
# 150/150 [==============================] - ETA: 0s - loss: 1.6975 - accuracy: 0.4662
# Epoch 00020: val_loss did not improve from 1.68119
# 150/150 [==============================] - 6s 42ms/step - loss: 1.6975 - accuracy: 0.4662 - val_loss: 1.6846 - val_accuracy: 0.4706
# Epoch 21/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6950 - accuracy: 0.4680
# Epoch 00021: val_loss did not improve from 1.68119
# 150/150 [==============================] - 6s 42ms/step - loss: 1.6949 - accuracy: 0.4682 - val_loss: 1.6892 - val_accuracy: 0.4701
# Epoch 22/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6731 - accuracy: 0.4705
# Epoch 00022: val_loss did not improve from 1.68119
# 150/150 [==============================] - 6s 42ms/step - loss: 1.6733 - accuracy: 0.4705 - val_loss: 1.6981 - val_accuracy: 0.4627
# Epoch 23/60
# 150/150 [==============================] - ETA: 0s - loss: 1.6681 - accuracy: 0.4739
# Epoch 00023: val_loss did not improve from 1.68119
# 150/150 [==============================] - 6s 42ms/step - loss: 1.6681 - accuracy: 0.4739 - val_loss: 1.7097 - val_accuracy: 0.4610
# Epoch 24/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6516 - accuracy: 0.4793
# Epoch 00024: val_loss improved from 1.68119 to 1.66651, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.6519 - accuracy: 0.4792 - val_loss: 1.6665 - val_accuracy: 0.4801
# Epoch 25/60
# 150/150 [==============================] - ETA: 0s - loss: 1.6289 - accuracy: 0.4854
# Epoch 00025: val_loss improved from 1.66651 to 1.66199, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.6289 - accuracy: 0.4854 - val_loss: 1.6620 - val_accuracy: 0.4769
# Epoch 26/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6215 - accuracy: 0.4872
# Epoch 00026: val_loss improved from 1.66199 to 1.64665, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.6205 - accuracy: 0.4875 - val_loss: 1.6467 - val_accuracy: 0.4804
# Epoch 27/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6051 - accuracy: 0.4912
# Epoch 00027: val_loss improved from 1.64665 to 1.62357, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.6056 - accuracy: 0.4909 - val_loss: 1.6236 - val_accuracy: 0.4913
# Epoch 28/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.6007 - accuracy: 0.4926
# Epoch 00028: val_loss improved from 1.62357 to 1.61646, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.6009 - accuracy: 0.4926 - val_loss: 1.6165 - val_accuracy: 0.4935
# Epoch 29/60
# 150/150 [==============================] - ETA: 0s - loss: 1.5868 - accuracy: 0.4960
# Epoch 00029: val_loss did not improve from 1.61646
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5868 - accuracy: 0.4960 - val_loss: 1.6296 - val_accuracy: 0.4891
# Epoch 30/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5786 - accuracy: 0.5007
# Epoch 00030: val_loss did not improve from 1.61646
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5784 - accuracy: 0.5009 - val_loss: 1.6538 - val_accuracy: 0.4795
# Epoch 31/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5620 - accuracy: 0.5038
# Epoch 00031: val_loss improved from 1.61646 to 1.60656, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 7s 44ms/step - loss: 1.5615 - accuracy: 0.5038 - val_loss: 1.6066 - val_accuracy: 0.4995
# Epoch 32/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5588 - accuracy: 0.5027
# Epoch 00032: val_loss did not improve from 1.60656
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5581 - accuracy: 0.5027 - val_loss: 1.6597 - val_accuracy: 0.4775
# Epoch 33/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5573 - accuracy: 0.5056
# Epoch 00033: val_loss did not improve from 1.60656
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5578 - accuracy: 0.5056 - val_loss: 1.6275 - val_accuracy: 0.4903
# Epoch 34/60
# 150/150 [==============================] - ETA: 0s - loss: 1.5359 - accuracy: 0.5118
# Epoch 00034: val_loss did not improve from 1.60656
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5359 - accuracy: 0.5118 - val_loss: 1.6278 - val_accuracy: 0.4861
# Epoch 35/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5192 - accuracy: 0.5168
# Epoch 00035: val_loss improved from 1.60656 to 1.59096, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 6s 43ms/step - loss: 1.5196 - accuracy: 0.5166 - val_loss: 1.5910 - val_accuracy: 0.4997
# Epoch 36/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.5150 - accuracy: 0.5205
# Epoch 00036: val_loss did not improve from 1.59096
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5154 - accuracy: 0.5203 - val_loss: 1.6332 - val_accuracy: 0.4939
# Epoch 37/60
# 150/150 [==============================] - ETA: 0s - loss: 1.5107 - accuracy: 0.5189
# Epoch 00037: val_loss did not improve from 1.59096
# 150/150 [==============================] - 6s 42ms/step - loss: 1.5107 - accuracy: 0.5189 - val_loss: 1.5914 - val_accuracy: 0.4949
# Epoch 38/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4970 - accuracy: 0.5212
# Epoch 00038: val_loss did not improve from 1.59096
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4970 - accuracy: 0.5212 - val_loss: 1.5925 - val_accuracy: 0.5028
# Epoch 39/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4877 - accuracy: 0.5263
# Epoch 00039: val_loss improved from 1.59096 to 1.55128, saving model to tl_model_v1.weights.best.hdf5
# 150/150 [==============================] - 7s 44ms/step - loss: 1.4877 - accuracy: 0.5263 - val_loss: 1.5513 - val_accuracy: 0.5139
# Epoch 40/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4815 - accuracy: 0.5270
# Epoch 00040: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4815 - accuracy: 0.5270 - val_loss: 1.5901 - val_accuracy: 0.5005
# Epoch 41/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4760 - accuracy: 0.5273
# Epoch 00041: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4760 - accuracy: 0.5273 - val_loss: 1.5624 - val_accuracy: 0.5124
# Epoch 42/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.4682 - accuracy: 0.5304
# Epoch 00042: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4683 - accuracy: 0.5303 - val_loss: 1.5771 - val_accuracy: 0.5069
# Epoch 43/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.4598 - accuracy: 0.5312
# Epoch 00043: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4595 - accuracy: 0.5313 - val_loss: 1.5666 - val_accuracy: 0.5104
# Epoch 44/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4435 - accuracy: 0.5358
# Epoch 00044: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4435 - accuracy: 0.5358 - val_loss: 1.5751 - val_accuracy: 0.5082
# Epoch 45/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.4463 - accuracy: 0.5376
# Epoch 00045: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4464 - accuracy: 0.5376 - val_loss: 1.6049 - val_accuracy: 0.4990
# Epoch 46/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4388 - accuracy: 0.5401
# Epoch 00046: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4388 - accuracy: 0.5401 - val_loss: 1.5916 - val_accuracy: 0.5079
# Epoch 47/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.4282 - accuracy: 0.5430
# Epoch 00047: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 41ms/step - loss: 1.4278 - accuracy: 0.5432 - val_loss: 1.5539 - val_accuracy: 0.5142
# Epoch 48/60
# 149/150 [============================>.] - ETA: 0s - loss: 1.4201 - accuracy: 0.5467
# Epoch 00048: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4200 - accuracy: 0.5466 - val_loss: 1.5835 - val_accuracy: 0.5043
# Epoch 49/60
# 150/150 [==============================] - ETA: 0s - loss: 1.4192 - accuracy: 0.5443
# Epoch 00049: val_loss did not improve from 1.55128
# 150/150 [==============================] - 6s 42ms/step - loss: 1.4192 - accuracy: 0.5443 - val_loss: 1.5630 - val_accuracy: 0.5106
# 313/313 - 2s - loss: 1.5513 - accuracy: 0.5139 - 2s/epoch - 6ms/step

# %%
# Transfer learning: VGG16 entrenado usando ImageNet; se usa sin su top layer.
def init_VGG16_model(summary):
  VGG16_MODEL=tf.keras.applications.VGG16(input_shape=(img_rows, img_cols, img_channels), include_top=False, weights='imagenet')

  # Habilitar conv layers
  VGG16_MODEL.trainable=True

  dropout_layer = tf.keras.layers.Dropout(rate = 0.50)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para daterminación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = tf.keras.layers.Dense(len(Coarse_labels),activation='softmax')
  model = tf.keras.Sequential([VGG16_MODEL, dropout_layer, global_average_layer, prediction_layer])

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.00005), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

VGG16_MODEL = init_VGG16_model(summary = True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  dropout_3 (Dropout)         (None, 1, 1, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 14,724,948
# Trainable params: 14,724,948
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGG16_MODEL_history = train_model(VGG16_MODEL, 15, 400, 40)
test_loss_VGG16, test_acc_VGG16 = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/15
# 400/400 [==============================] - ETA: 0s - loss: 1.9279 - accuracy: 0.4077
# Epoch 00001: val_loss improved from 1.55128 to 1.41466, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 59s 137ms/step - loss: 1.9279 - accuracy: 0.4077 - val_loss: 1.4147 - val_accuracy: 0.5623
# Epoch 2/15
# 400/400 [==============================] - ETA: 0s - loss: 1.3103 - accuracy: 0.5909
# Epoch 00002: val_loss improved from 1.41466 to 1.16504, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 52s 129ms/step - loss: 1.3103 - accuracy: 0.5909 - val_loss: 1.1650 - val_accuracy: 0.6345
# Epoch 3/15
# 400/400 [==============================] - ETA: 0s - loss: 1.0675 - accuracy: 0.6652
# Epoch 00003: val_loss improved from 1.16504 to 1.04365, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 52s 129ms/step - loss: 1.0675 - accuracy: 0.6652 - val_loss: 1.0437 - val_accuracy: 0.6676
# Epoch 4/15
# 400/400 [==============================] - ETA: 0s - loss: 0.8843 - accuracy: 0.7215
# Epoch 00004: val_loss improved from 1.04365 to 0.98399, saving model to tl_model_v1.weights.best.hdf5
# 400/400 [==============================] - 52s 129ms/step - loss: 0.8843 - accuracy: 0.7215 - val_loss: 0.9840 - val_accuracy: 0.6872
# Epoch 5/15
# 400/400 [==============================] - ETA: 0s - loss: 0.7321 - accuracy: 0.7671
# Epoch 00005: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 129ms/step - loss: 0.7321 - accuracy: 0.7671 - val_loss: 0.9859 - val_accuracy: 0.6942
# Epoch 6/15
# 400/400 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.8097
# Epoch 00006: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.5985 - accuracy: 0.8097 - val_loss: 1.0048 - val_accuracy: 0.6976
# Epoch 7/15
# 400/400 [==============================] - ETA: 0s - loss: 0.4692 - accuracy: 0.8500
# Epoch 00007: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.4692 - accuracy: 0.8500 - val_loss: 1.0191 - val_accuracy: 0.7023
# Epoch 8/15
# 400/400 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8925
# Epoch 00008: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.3392 - accuracy: 0.8925 - val_loss: 1.0863 - val_accuracy: 0.7067
# Epoch 9/15
# 400/400 [==============================] - ETA: 0s - loss: 0.2592 - accuracy: 0.9168
# Epoch 00009: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.2592 - accuracy: 0.9168 - val_loss: 1.1050 - val_accuracy: 0.7092
# Epoch 10/15
# 400/400 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9426
# Epoch 00010: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.1813 - accuracy: 0.9426 - val_loss: 1.2328 - val_accuracy: 0.7065
# Epoch 11/15
# 400/400 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9567
# Epoch 00011: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.1340 - accuracy: 0.9567 - val_loss: 1.3436 - val_accuracy: 0.6992
# Epoch 12/15
# 400/400 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9683
# Epoch 00012: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.1005 - accuracy: 0.9683 - val_loss: 1.3982 - val_accuracy: 0.7097
# Epoch 13/15
# 400/400 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9722
# Epoch 00013: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.0882 - accuracy: 0.9722 - val_loss: 1.4587 - val_accuracy: 0.7151
# Epoch 14/15
# 400/400 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9750
# Epoch 00014: val_loss did not improve from 0.98399
# 400/400 [==============================] - 51s 128ms/step - loss: 0.0770 - accuracy: 0.9750 - val_loss: 1.4233 - val_accuracy: 0.7091
# 313/313 - 2s - loss: 1.5513 - accuracy: 0.5139 - 2s/epoch - 5ms/step

# %%
# Transfer learning: VGG16 entrenado usando ImageNet; se usa sin su top layer, pero se añade fine-tuning (ver documento)
def init_VGG16_model_finetuning(summary, fine_tune=0):
  VGG16_MODEL_FT=tf.keras.applications.VGG16(input_shape=(img_rows, img_cols, img_channels), include_top=False, weights='imagenet')

  # Define cuántas capas se congelan durante el entrenamiento. Las capas de la base convolucional 
  # pasan de ser entrenables a no entrenables dependiendo del valor de fine-tuning.
  if fine_tune > 0:
    for layer in VGG16_MODEL_FT.layers[:-fine_tune]:
      layer.trainable = False
  else:
    for layer in VGG16_MODEL_FT.layers:
      layer.trainable = False

  top_model = VGG16_MODEL_FT.output
  top_model = Flatten(name="flatten")(top_model)
  top_model = Dense(4096, activation='relu')(top_model)
  top_model = Dense(1072, activation='relu')(top_model)
  top_model = Dropout(0.4)(top_model)

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para 
  # determinación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = Dense(len(Coarse_labels), activation='softmax')(top_model)
  model = tf.keras.Model(inputs=VGG16_MODEL_FT.input, outputs=prediction_layer)

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.00001), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

VGG16_MODEL_FT = init_VGG16_model_finetuning(summary = True, fine_tune=3)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_8 (Dense)             (None, 4096)              2101248
#
#  dense_9 (Dense)             (None, 1072)              4391984
#
#  dropout_5 (Dropout)         (None, 1072)              0
#
#  dense_10 (Dense)            (None, 20)                21460
#
# =================================================================
# Total params: 21,229,380
# Trainable params: 11,234,308
# Non-trainable params: 9,995,072
# _________________________________________________________________

# %%
VGG16_MODEL_FT_history = train_model(VGG16_MODEL_FT, 15, 150, 10)
test_loss_VGG16_FT, test_acc_VGG16_FT = model.evaluate(test_images, test_labels, verbose=1)
# Out:
# Epoch 1/15
# 150/150 [==============================] - ETA: 0s - loss: 2.5955 - accuracy: 0.2130
# Epoch 00001: val_loss did not improve from 0.98399
# 150/150 [==============================] - 35s 205ms/step - loss: 2.5955 - accuracy: 0.2130 - val_loss: 2.1326 - val_accuracy: 0.3564
# Epoch 2/15
# 150/150 [==============================] - ETA: 0s - loss: 2.0493 - accuracy: 0.3648
# Epoch 00002: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 130ms/step - loss: 2.0493 - accuracy: 0.3648 - val_loss: 1.8888 - val_accuracy: 0.4167
# Epoch 3/15
# 150/150 [==============================] - ETA: 0s - loss: 1.8797 - accuracy: 0.4107
# Epoch 00003: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 130ms/step - loss: 1.8797 - accuracy: 0.4107 - val_loss: 1.7748 - val_accuracy: 0.4488
# Epoch 4/15
# 150/150 [==============================] - ETA: 0s - loss: 1.7793 - accuracy: 0.4401
# Epoch 00004: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.7793 - accuracy: 0.4401 - val_loss: 1.7076 - val_accuracy: 0.4660
# Epoch 5/15
# 150/150 [==============================] - ETA: 0s - loss: 1.7087 - accuracy: 0.4627
# Epoch 00005: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 130ms/step - loss: 1.7087 - accuracy: 0.4627 - val_loss: 1.6566 - val_accuracy: 0.4820
# Epoch 6/15
# 150/150 [==============================] - ETA: 0s - loss: 1.6543 - accuracy: 0.4803
# Epoch 00006: val_loss did not improve from 0.98399
# 150/150 [==============================] - 19s 130ms/step - loss: 1.6543 - accuracy: 0.4803 - val_loss: 1.6124 - val_accuracy: 0.4950
# Epoch 7/15
# 150/150 [==============================] - ETA: 0s - loss: 1.6086 - accuracy: 0.4932
# Epoch 00007: val_loss did not improve from 0.98399
# 150/150 [==============================] - 19s 130ms/step - loss: 1.6086 - accuracy: 0.4932 - val_loss: 1.5807 - val_accuracy: 0.5021
# Epoch 8/15
# 150/150 [==============================] - ETA: 0s - loss: 1.5671 - accuracy: 0.5043
# Epoch 00008: val_loss did not improve from 0.98399
# 150/150 [==============================] - 19s 130ms/step - loss: 1.5671 - accuracy: 0.5043 - val_loss: 1.5567 - val_accuracy: 0.5079
# Epoch 9/15
# 150/150 [==============================] - ETA: 0s - loss: 1.5302 - accuracy: 0.5159
# Epoch 00009: val_loss did not improve from 0.98399
# 150/150 [==============================] - 19s 130ms/step - loss: 1.5302 - accuracy: 0.5159 - val_loss: 1.5357 - val_accuracy: 0.5141
# Epoch 10/15
# 150/150 [==============================] - ETA: 0s - loss: 1.4979 - accuracy: 0.5290
# Epoch 00010: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.4979 - accuracy: 0.5290 - val_loss: 1.5178 - val_accuracy: 0.5201
# Epoch 11/15
# 150/150 [==============================] - ETA: 0s - loss: 1.4691 - accuracy: 0.5363
# Epoch 00011: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.4691 - accuracy: 0.5363 - val_loss: 1.4985 - val_accuracy: 0.5283
# Epoch 12/15
# 150/150 [==============================] - ETA: 0s - loss: 1.4445 - accuracy: 0.5453
# Epoch 00012: val_loss did not improve from 0.98399
# 150/150 [==============================] - 19s 130ms/step - loss: 1.4445 - accuracy: 0.5453 - val_loss: 1.4774 - val_accuracy: 0.5343
# Epoch 13/15
# 150/150 [==============================] - ETA: 0s - loss: 1.4161 - accuracy: 0.5518
# Epoch 00013: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.4161 - accuracy: 0.5518 - val_loss: 1.4616 - val_accuracy: 0.5358
# Epoch 14/15
# 150/150 [==============================] - ETA: 0s - loss: 1.3923 - accuracy: 0.5597
# Epoch 00014: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.3923 - accuracy: 0.5597 - val_loss: 1.4474 - val_accuracy: 0.5415
# Epoch 15/15
# 150/150 [==============================] - ETA: 0s - loss: 1.3699 - accuracy: 0.5639
# Epoch 00015: val_loss did not improve from 0.98399
# 150/150 [==============================] - 20s 133ms/step - loss: 1.3699 - accuracy: 0.5639 - val_loss: 1.4403 - val_accuracy: 0.5453
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5513 - accuracy: 0.5139

# %%
# Esta celda fue inhabilitada debido a la exhaustividad de procesamiento; SEGUIR LOS SIGUIENTES PASOS SI SE DESEA TRABAJAR CON ESTE MODELO PREENTRENADO.
 
# Trabajar con Inception (una arquitectura CNN más moderna que VGG16) implicaría ajustar la forma de la entrada de las bases de CIFAR100 a, por lo menos, 75x75x3. 
# Para ello se sugiere hacer uso del siguiente dataset que ha aplicado un reescalamiento (256x256) a las imágenes, sin causar en nuestra máquina un consumo excesivo de recursos.
    # https://www.kaggle.com/ibraheemmoosa/cifar100-256x256
# Es necesario, si se continúa empleando Colab, importar dicho dataset a la consola virtual. Para ello, recomendamos visualizar el siguiente link donde se detalla paso a paso su subida.
    # https://www.kaggle.com/ibraheemmoosa/cifar100-256x256
# Una vez logrado, deberemos ajustar el punto de carga, el input_shape del modelo (256x256x3) e hiperparámetros (de ser necesario). 
# Enseguida, se correrá esta celda. Notése que se han predefinido las dimensiones de la entrada. 

# Transfer learning: Inception (versión 3) entrenado usando ImageNet; se usa sin su top layer, al igual que el modelo preentrenado anterior.
def init_Inception_model(summary):
  Inception_MODEL = InceptionV3(input_shape=(256, 256, 3), include_top=False, weights='imagenet')

  # Habilitar conv layers
  Inception_MODEL.trainable=True

  dropout_layer = tf.keras.layers.Dropout(rate = 0.2)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  # Se sobrepone la top layer de CIFAR100 (dense de 20 neuronas, activación softmax para daterminación de clases = 1.0) junto con el model sequential de la red de transferencia
  prediction_layer = tf.keras.layers.Dense(len(Coarse_labels),activation='softmax')
  model = tf.keras.Sequential([Inception_MODEL, dropout_layer, global_average_layer, prediction_layer])

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.00005), loss=tf.keras.losses.sparse_categorical_crossentropy, metrics=["accuracy"])
  if summary: 
    model.summary()
  return model

Inception_MODEL = init_Inception_model(summary = True)

# %%
plt.plot(SIMPLE_MODEL_history.history['accuracy'], label='accuracy')
plt.plot(SIMPLE_MODEL_history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(VGG16_MODEL_history.history['accuracy'], label='accuracy_(with VGG16)')
plt.plot(VGG16_MODEL_history.history['val_accuracy'], label = 'val_accuracy_(with VGG16)')
plt.plot(VGG16_MODEL_FT_history.history['accuracy'], label='accuracy_(with VGG16)/Fine-tuning')
plt.plot(VGG16_MODEL_FT_history.history['val_accuracy'], label = 'val_accuracy_(with VGG16)/Fine-tuning')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
#Arreglo de valores de exactitud para validación/testeo
tz_MX = pytz.timezone('America/Mexico_City')
now = datetime.now(tz_MX)
current_time = now.strftime("%d/%m/%Y a las %H:%M:%S")

historyarray.append(f'{current_time}: {round((test_acc * 100), 2)}%')

print(test_acc, historyarray)
# Out:
# 0.19259999692440033 [0, '18/11/2021 a las 13:14:47: 19.26%']

# %% [markdown]
# **Consultas y sitios web**
#
#
# ```
# 1. https://www.programiz.com/python-programming/datetime/current-datetime
# 2. https://www.tensorflow.org/tutorials/images/cnn?hl=es-419
# 3. https://www.tensorflow.org/api_docs/python/tf/keras/activations?hl=es-419)
# 4. https://gist.github.com/heyalexej/8bf688fd67d7199be4a1682b3eec7568
# 5. https://neurohive.io/en/popular-networks/vgg16/
# 6. https://www.cs.toronto.edu/~kriz/cifar.html
# 7. https://towardsdatascience.com/cifar-100-pre-processing-for-image-recognition-task-68015b43d658
# ```
